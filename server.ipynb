# %%
import socket
import numpy as np
import cv2 as cv
import threading

# %%
s = socket.socket()
s.bind(("", 1234))
s.listen()
session, address = s.accept() #accepting request from any server
print(session.recv(2046)) 
cameraIndex = 'http://192.168.225.42:8080/video' # using camera from IPCamera App
camera = cv.VideoCapture(cameraIndex) # staritng camera

def sender():
    while True:
        status, photo = camera.read()
        photo = cv.resize(photo, (640, 480))
        print(photo.shape)
        if status:
            session.send(np.ndarray.tobytes(photo))
        else: 
            print("Could not get frame")

def receiver():
    framesLost = 0
    print("Entered Into Live Stream")
    while True:
        framesLost += 1
        data = session.recv(100000000)
        if(data == b'finished'):
            print("Finished")
            camera.release()
            session.close()
        else:
            photo =  np.frombuffer(data, dtype=np.uint8)
            if len(photo) == 640*480*3:
                cv.imshow('From Client', photo.reshape(480, 640, 3))
                if cv.waitKey(1) == 13:
                    session.send(b'finished')
                    camera.release()
                    cv.destroyAllWindows()
                    break
            else:
                print("Lost {} frames".format(framesLost) )
                
threading.Thread(target=sender).start()
threading.Thread(target=receiver).start()
# Out:
# b'connected'
# Entered Into Live Stream
# Lost 1 frames
# Lost 2 frames
# Exception in thread Thread-4:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/opt/anaconda3/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-1ea871e52257>", line 12, in sender
#     photo = cv.resize(photo, (640, 480))
# cv2.error: OpenCV(4.5.2) /private/var/folders/24/8k48jl6d249_n_qfxwsl6xvm0000gn/T/pip-req-build-9poqjr9l/opencv/modules/imgproc/src/resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
# Lost 3 frames
# Lost 4 frames
# Lost 5 frames
# Lost 6 frames
# Lost 7 frames
# Lost 8 frames
# Lost 9 frames
# Lost 10 frames
# Lost 11 frames
# Lost 12 frames
# Lost 13 frames
# Lost 14 frames
# Lost 15 frames
# Lost 16 frames
# Lost 17 frames
# Lost 18 frames
# Lost 19 frames
# Lost 20 frames
# Lost 21 frames
# Lost 22 frames
# Lost 23 frames
# Lost 24 frames
# Lost 25 frames
# Lost 26 frames
# Lost 27 frames
# Lost 28 frames
# Lost 29 frames
# Lost 30 frames
# Lost 31 frames
# Lost 32 frames
# Lost 33 frames
# Lost 34 frames
# Lost 35 frames
# Lost 36 frames
# Lost 37 frames
# Lost 38 frames
# Lost 39 frames
# Lost 40 frames
# Lost 41 frames
# Lost 42 frames
# Lost 43 frames
# Lost 44 frames
# Lost 45 frames
# Lost 46 frames
# Lost 47 frames
# Lost 48 frames
# Lost 49 frames
# Lost 50 frames
# Lost 51 frames
# Lost 52 frames
# Lost 53 frames
# Lost 54 frames
# Lost 55 frames
# Lost 56 frames
# Lost 57 frames
# Lost 58 frames
# Lost 59 frames
# Lost 60 frames
# Lost 61 frames
# Lost 62 frames
# Lost 63 frames
# Lost 64 frames
# Lost 65 frames
# Lost 66 frames
# Lost 67 frames
# Lost 68 frames
# Lost 69 frames
# Lost 70 frames
# Lost 71 frames
# Lost 72 frames
# Lost 73 frames
# Lost 74 frames
# Lost 75 frames
# Lost 76 frames
# Lost 77 frames
# Lost 78 frames
# Lost 79 frames
# Lost 80 frames
# Lost 81 frames
# Lost 82 frames
